# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pyttsx3
import time
correct = []
incorrect =[]
right = []
wrong = []
r = 1
b = 0
print("Press 1 for Yes")
print("Press 2 for No")
print("\n\n------------------------------------------------------------\n")
start = input("Do you want to start the game :")
if start == "1":
    print("\n\nLoading.....")
    time.sleep(10)
    print("Terms and Conditions..")
    print("\n\n Your game will start in 20 seconds. In this game you have to give the answer of Twenty Eight questions for Each Correct Answer incriment of 1 marks in your score and for each Wrong Answer there will be a deduction of -0.25 marks.\n\nEnjoy Your Game......")
    time.sleep(20)
    while r<=28:
        if r == 1:
            text = ("Q1. Name the Capital of Rajasthan?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Jaipur":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q1")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q1")
                wrong.append(-0.25)
        elif r == 2:
            print("\n\n------------------------------------\n")
            text = ("Q2. Name the Capital of Maharashtra?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Mumbai":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q2")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q2")
                wrong.append(-0.25)
        elif r == 3:
            print("\n\n------------------------------------\n")
            text = ("Q3. Name the Capital of Andhra Pradesh?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Amaravati":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q3")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q3")
                wrong.append(-0.25)
        elif r == 4:
            print("\n\n------------------------------------\n")
            text = ("Q4. Name the Capital of Arunachal Pradesh?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Itanagar":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q4")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q4")
                wrong.append(-0.25)
        elif r == 5:
            print("\n\n------------------------------------\n")
            text = ("Q5. Name the Capital of Assam?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Dispur":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q5")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q5")
                wrong.append(-0.25)
        elif r == 6:
            print("\n\n------------------------------------\n")
            text = ("Q6. Name the Capital of Bihar?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Patna":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q6")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q6")
                wrong.append(-0.25)
        elif r == 7:
            print("\n\n------------------------------------\n")
            text = ("Q7. Name the Capital of Chhattisgarh?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Raipur":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q7")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q7")
                wrong.append(-0.25)
        elif r == 8:
            print("\n\n------------------------------------\n")
            text = ("Q8. Name the Capital of Goa?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Panaji":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q8")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q8")
                wrong.append(-0.25)
        elif r == 9:
            print("\n\n------------------------------------\n")
            text = ("Q9. Name the Capital of Gujarat?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Gandhinagar":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q9")
                right.append(1)
            else:
                print("\n\n------------------------------------\n")
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q9")
                wrong.append(-0.25)
        elif r == 10:
            print("\n\n------------------------------------\n")
            text = ("Q10. Name the Capital of Harayana?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Chandigarh":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q10")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q10")
                wrong.append(-0.25)
        elif r == 11:
            print("\n\n------------------------------------\n")
            text = ("Q11. Name the Capital of Himachal Pradesh?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Shimla":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q11")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q11")
                wrong.append(-0.25)
        elif r == 12:
            print("\n\n------------------------------------\n")
            text = ("Q12. Name the Capital of Jharkhand?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Ranchi":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q12")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q12")
                wrong.append(-0.25)
        elif r == 13:
            print("\n\n------------------------------------\n")
            text = ("Q13. Name the Capital of Karnataka?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Bengaluru":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q13")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q13")
                wrong.append(-0.25)
        elif r == 14:
            print("\n\n------------------------------------\n")
            text = ("Q14. Name the Capital of Kerala?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Thiruvananthapuram":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q14")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q14")
                wrong.append(-0.25)
        elif r == 15:
            print("\n\n------------------------------------\n")
            text = ("Q15. Name the Capital of Madhya Pradesh?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Bhopal":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q15")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q15")
                wrong.append(-0.25)
        elif r == 16:
            print("\n\n------------------------------------\n")
            text = ("Q16. Name the Capital of Manipur?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Imphal":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q16")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q16")
                wrong.append(-0.25)
        elif r == 17:
            print("\n\n------------------------------------\n")
            text = ("Q17. Name the Capital of Meghalaya?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Shillong":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q17")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q17")
                wrong.append(-0.25)
        elif r == 18:
            print("\n\n------------------------------------\n")
            text = ("Q18. Name the Capital of Mizoram?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Aizwal":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q18")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q18")
                wrong.append(-0.25)
        elif r == 19:
            print("\n\n------------------------------------\n")
            text = ("Q19. Name the Capital of Nagaland?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Kohima":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q19")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q19")
                wrong.append(-0.25)
        elif r == 20:
            print("\n\n------------------------------------\n")
            text = ("Q20. Name the Capital of Odisha?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Bhubaneswar":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q20")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q20")
                wrong.append(-0.25)
        elif r == 21:
            print("\n\n------------------------------------\n")
            text = ("Q21. Name the Capital of Punjab?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Chandigarh":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q21")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q21")
                wrong.append(-0.25)
        elif r == 22:
            print("\n\n------------------------------------\n")
            text = ("Q22. Name the Capital of Sikkim?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Gangtok":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q22")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q22")
                wrong.append(-0.25)
        elif r == 23:
            print("\n\n------------------------------------\n")
            text = ("Q23. Name the Capital of Tamil Nadu?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Chennai":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q23")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q23")
                wrong.append(-0.25)
        elif r == 24:
            print("\n\n------------------------------------\n")
            text = ("Q24. Name the Capital of Telangana?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Hyderabad":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q24")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q24")
                wrong.append(-0.25)
        elif r == 25:
            print("\n\n------------------------------------\n")
            text = ("Q25. Name the Capital of Tripura?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Agartala":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q25")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q25")
                wrong.append(-0.25)
        elif r == 26:
            print("\n\n------------------------------------\n")
            text = ("Q26. Name the Capital of Uttar Pradesh?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Lucknow":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q26")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q26")
                wrong.append(-0.25)
        elif r == 27:
            print("\n\n------------------------------------\n")
            text = ("Q27. Name the Capital of Uttrakhand?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Dehradun":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q27")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q27")
                wrong.append(-0.25)
        elif r == 28:
            print("\n\n------------------------------------\n")
            text = ("Q28. Name the Capital of West Bengal?")
            print(text)
            a = pyttsx3.init()
            a.say(text)
            a.runAndWait()
            Ans = input("Enter the Answer Here - ")
            if Ans ==  "Kolkata":
                rr = "Right Answer"
                a.say(rr)
                a.runAndWait()
                b = b+1
                correct.append("Q28")
                right.append(1)
            else:
                rr = "Wrong Answer"
                a.say(rr)
                a.runAndWait()
                b = b-0.25
                incorrect.append("Q28")
                wrong.append(-0.25)
        r+=1
    d1 = {"Correct Answers":correct,
         "R":right}
    d2 = {"Incorrect Answers":incorrect,
        "W":wrong}
    print("Your result is :")
    print("\n\n--------------------------------------------------------\n")
    df=pd.DataFrame(d1)
    de = pd.DataFrame(d2)
    print(df,"\n\n",de)
    print("\t\t\t\t\tTotal Score -",b)
    if b >=25:
        print("Excellent...You Have a Good Score.")
        print("\U0001f600")
    elif b >=20:
        print("Good...Please Come back again... Thank You!!!")
        print("\U0001f600")
    elif b<<20:
        print("Better luck next time.... Thank You for Playing..")
        print("\U0001f600")
elif start == "2":
    print("Okay!!! Please Come back Again...")
else:
    print("Invalid Input...Please Rerun the Game..")
# Out:
# Press 1 for Yes
# Press 2 for No
#
#
# ------------------------------------------------------------
#
# Do you want to start the game :1
#
#
# Loading.....
# Terms and Conditions..
#
#
#  Your game will start in 20 seconds. In this game you have to give the answer of Twenty Eight questions for Each Correct Answer incriment of 1 marks in your score and for each Wrong Answer there will be a deduction of -0.25 marks.
#
# Enjoy Your Game......
# Q1. Name the Capital of Rajasthan?
# Enter the Answer Here - Jaipur
#
#
# ------------------------------------
#
# Q2. Name the Capital of Maharashtra?
# Enter the Answer Here - Mumbai
#
#
# ------------------------------------
#
# Q3. Name the Capital of Andhra Pradesh?
# Enter the Answer Here - Amaravati
#
#
# ------------------------------------
#
# Q4. Name the Capital of Arunachal Pradesh?
# Enter the Answer Here - Itanagar
#
#
# ------------------------------------
#
# Q5. Name the Capital of Assam?
# Enter the Answer Here - Dispur
#
#
# ...
